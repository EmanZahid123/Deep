# %% [markdown]
# ## Gradient Descent Assignment
# In this assignment, you will implement and experiment with Gradient Descent on a simulated dataset. Your task is to complete the missing sections of the code, understand the role of each part of the algorithm, and tweak the hyperparameters to see their effect.
#
# ## Objectives:
# Understand and implement the Gradient Descent algorithm.
# Visualize how the cost function decreases with iterations.
# Tweak learning rates and number of iterations to observe the impact.

# %% [markdown]
# ## Instructions:
# - Complete the code where indicated.
# - Run each cell to observe the results.
# - Use assert statements to validate your code.

# %% [markdown]
# ### Part 1: Setting up the Dataset
# In this section, we'll import necessary libraries and load the dataset.

# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Simulated real-world dataset with multiple features:
X = np.array([
    [750, 3, 30, 15],
    [850, 3, 25, 12],
    [900, 4, 20, 10],
    [1200, 4, 18, 8],
    [1500, 5, 10, 5],
    [2000, 5, 5, 3],
    [2300, 6, 3, 2],
    [3000, 6, 2, 1],
    [3500, 7, 1, 1],
    [4000, 8, 1, 0]
])  # Features: [Size, Bedrooms, Age, Distance to City Center]

y = np.array([150, 175, 200, 300, 375, 480, 525, 650, 720, 800])  # Price of the house in 1000s of dollars
print(X.shape)
print(y.shape)
# Out:
# (10, 4)
# (10,)

# %% [markdown]
# In this section, we’ll import necessary libraries and load the dataset.
#
# $$ X_{norm} = \frac{X - \mu}{\sigma} $$
#
# where mu is the mean and sigma is the standard deviation of the features.

# %%
# Normalize features for better convergence
X_norm = (X - X.mean(axis=0)) / X.std(axis=0)
# Add a column of ones to X_norm to account for theta0 (intercept)
X_b = np.c_[np.ones(X_norm.shape[0]), X_norm]  # Add intercept term
print(X_b.shape)
# Out:
# (10, 5)

# %% [markdown]
# ### Part 2: Gradient Descent Algorithm
# Now, we will implement the Gradient Descent algorithm.
#
# ### Useful Equations
#
# $$ Y_{prediction} = f(X) = W.X $$
#
# $$ J (Cost Function) = \frac{1}{2m}  (Y_{prediction}  - Y)^2 $$
#
# $$ \begin{align}
# Gradient &(\frac{\partial J(W)}{\partial W}) = \frac{1}{m}  (Y_{prediction} - Y).X\\
# \end{align} $$
#
# $$ \begin{align*}
#   W &= W -  \alpha .(\frac{\partial J(W)}{\partial W})
#   \end{align*} $$
#
# Complete the missing parts of the code below:

# %%
# Initialize parameters (weights vector) with zeros
theta = np.zeros(X_b.shape[1])
print(theta)
print(theta.shape)
# Define learning rate and number of iterations
alpha = 0.1  # You can experiment with this
iterations = 1500 # Try changing this value

# Gradient descent function
def gradient_descent(X, y, theta, alpha, iterations):
    m = len(y)  # Number of training examples
    cost_history = []  # To store the cost at each iteration

    for i in range(iterations):
        # Predicted values 
        y_pred = X.dot(theta)
        #the dot product X.theta the result is a 10×1 vector, representing the predicted values for each of the 10 training examples. 
       

        # Compute the error (difference between predicted and actual values)
        error = y_pred - y
        # Compute gradients 
        gradients = (1/(m))*(X.T.dot(error))# x is 10*5 and error is 10*1, take transpaose for their multiplication

        # Update the parameters (theta)
        theta = theta - alpha*gradients

        # Compute the cost function (Mean Squared Error) and append to history
.73094643501815, 157.07823433125574, 156.4318941155722, 155.79178610469216, 155.15777511284716, 154.52973029508138, 153.90752499608737, 153.29103660436883, 152.68014641154772, 152.07473947663644, 151.47470449508828, 150.87993367247168, 150.29032260259245, 149.70577014991633, 149.1261783361348, 148.5514522307249, 147.9814998453719, 147.4162320321091, 146.85556238504452, 146.29940714555593, 145.74768511081678, 145.20031754555495, 144.65722809690968, 144.11834271229168, 143.58358956013575, 143.05289895344023, 142.5262032760061, 142.00343691125738, 141.4845361735856, 140.96943924209626, 140.45808609669152, 139.95041845640094, 139.44637971988303, 138.94591490801906, 138.44897060852, 137.95549492249165, 137.46543741286922, 136.97874905466765, 136.49538218698157, 136.01529046666954, 135.53842882366763, 135.06475341786933, 134.59422159752242, 134.1267918590877, 133.66242380850318, 133.20107812380908, 132.7427165190865, 132.28730170965693, 131.8347973785086, 131.38516814389075, 130.93837952805478, 130.4943979270822, 130.05319058177236, 129.6147255495549, 129.17897167737644, 128.74589857554346, 128.31547659248108, 127.88767679036823, 127.46247092163237, 127.03983140626154, 126.61973130991369, 126.20214432278361, 125.78704473921655, 125.3744074380283, 124.96420786351291, 124.55642200711605 ...

# %% [markdown]
# ### Part 3: Visualizing the Cost Function
# Let's plot the cost function to observe how it decreases over time.

# %%
plt.plot(range(iterations), cost_history)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function Over Iterations')
plt.show()

# Assert to check the final cost decreases
assert cost_history[-1] < cost_history[0], "Cost did not decrease!"

# %% [markdown]
# ### Part 4: Predictions and Visualization
# Now, we'll use the final parameters to make predictions

# %%
# Predicted prices using the final parameters
y_pred_final = X_b.dot(theta)

# Plotting actual vs predicted prices
plt.scatter(range(len(y)), y, color='blue', label='Actual Prices')
plt.plot(range(len(y)), y_pred_final, color='red', label='Predicted Prices')
plt.xlabel('House Index')
plt.ylabel('Price (in 1000s of dollars)')
plt.title('Actual vs Predicted House Prices')
plt.legend()
plt.show()

# Assert to check predictions length
assert len(y_pred_final) == len(y), "Prediction length mismatch!"

# %% [markdown]
# ### Part 6: Implementing Gradient Descent on Real-World Data (Ames Housing Dataset)
# In this section, you will apply the Gradient Descent algorithm to a real dataset from the Ames Housing dataset. Download the dataset from Kaggle and follow the steps below.

# %% [markdown]
# ## Instructions:
# Load the dataset and manually preprocess the data without using any third-party libraries like sklearn.
# Implement the Gradient Descent algorithm as you did for the simulated data.
# Visualize the cost function and make predictions.
# Experiment with hyperparameters and observe their effects.

# %% [markdown]
# ## Loading and Preprocessing the Dataset (Manual Processing)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the dataset
# Assuming the dataset is downloaded and named 'train.csv'
df = pd.read_csv('AmesHousing.csv')

# Select a few features (you can try different sets of features)

## Select Features by your own choice
features = ["Lot Area","House Style","Overall Qual","Bedroom AbvGr","Year Built"]
target = 'SalePrice'

#Making dataframe of features
df_features = df[features]

# %%
#Checking types of each feature
print(df_features.dtypes)
# Out:
# Lot Area          int64
# House Style      object
# Overall Qual      int64
# Bedroom AbvGr     int64
# Year Built        int64
# dtype: object

# %%
#Checking how many null values
print(df_features.isnull().sum())
# Out:
# Lot Area         0
# House Style      0
# Overall Qual     0
# Bedroom AbvGr    0
# Year Built       0
# dtype: int64

# %%
#Checking how many unique values
print(df_features.nunique())
# Out:
# Lot Area         1960
# House Style         8
# Overall Qual       10
# Bedroom AbvGr       8
# Year Built        118
# dtype: int64

# %%
#unique values in House Style
print(df_features["House Style"].unique())
#unique values in Overall Qual
print(df_features["Overall Qual"].unique())
#unique values in Bedroom AbvGr
print(df_features["Bedroom AbvGr"].unique())
# Out:
# ['1Story' '2Story' '1.5Fin' 'SFoyer' 'SLvl' '2.5Unf' '1.5Unf' '2.5Fin']
# [ 6  5  7  8  9  4  3  2 10  1]
# [3 2 1 4 6 5 0 8]

# %%
# Extracting features (keep as DataFrame for one-hot encoding)
X_real = df[features]
y_real = df[target].values  #numpy array

# Step 1: One-Hot Encoding 'House Style' manually
house_styles = X_real['House Style'].unique()  # Get unique categories
house_style_dummies = pd.DataFrame(0, index=X_real.index, columns=house_styles)

for style in house_styles:
    house_style_dummies[style] = (X_real['House Style'] == style).astype(int)

# Step 2: Drop the original 'House Style' column and concatenate encoded columns
X_real = X_real.drop(columns=['House Style'])
X_real = pd.concat([X_real, house_style_dummies], axis=1)

# Step 3: Convert X_real to a NumPy array for further processing
X_real = X_real.values

# Now X_real is a NumPy array and ready for use
print(X_real.shape)
# Out:
# (2930, 12)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_real, y_real, test_size=0.2, random_state=42)

# Normalize features for better convergence
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Add a column of ones for the intercept term
X_train_b = np.c_[np.ones(X_train_scaled.shape[0]), X_train_scaled]

print(X_train_b.shape)
# Out:
# (2344, 13)

# %% [markdown]
# ## Implementing Gradient Descent for Real-World Data

# %%
# Initialize parameters (weights vector) with zeros
theta_real = np.zeros(X_train_b.shape[1])

# Define learning rate and number of iterations (You can experiment with these values)
alpha_real = 0.01
iterations_real = 1000

# In case of having NaN values in the dataset, replace them with 0
X_train_b = np.nan_to_num(X_train_b)  # Replace NaNs with 0

# Use the gradient_descent function
theta_real, cost_history_real = gradient_descent(X_train_b, y_train, theta_real, alpha_real, iterations_real)
print(theta_real)
print(cost_history_real)

# Assert statement to check theta shape
assert theta_real.shape == (X_train_b.shape[1],), "Theta shape mismatch for real dataset!"
# Out:
# [ 1.78574498e+05  1.44320260e+04  5.19419749e+04  6.69206209e+03
#   1.29166801e+04  4.47102392e+02  3.54276588e+02  8.69151115e+02
#  -5.84961537e+02 -2.69337012e+03 -4.10585052e+01 -1.45281699e+03
#   2.16983208e+03]
# [18918672055.110283, 18535940396.11354, 18161820097.29438, 17796100752.505386, 17438577663.586792, 17089051667.590183, 16747328969.744675, 16413220981.961384, 16086544166.679914, 15767119885.867397, 15454774254.988121, 15149338001.768099, 14850646329.585638, 14558538785.325191, 14272859131.53759, 13993455222.75578, 13720178885.820545, 13452885804.076101, 13191435405.300604, 12935690753.241535, 12685518442.63072, 12440788497.558216, 12201374273.088877, 11967152360
445513.8056653, 1360711193.437347, 1352148819.5551798, 1343754962.9163532, 1335526263.4466465, 1327459428.822158, 1319551233.0809567, 1311798515.2639594, 1304198178.0844212, 1296747186.6253881, 1289442567.064505, 1282281405.425576, 1275260846.3562965, 1268378091.9315736, 1261630400.481885, 1255015085.4461267, 1248529514.248419, 1242171107.198341, 1235937336.4140983, 1229825724.7681131, 1223833844.8545618, 1217959317.9783795, 1212199813.1652687, 1206553046.192262 ...

# %% [markdown]
# ## Visualizing the Cost Function for Real Data

# %%
# Plotting the cost function over iterations for real data
plt.plot(range(iterations_real), cost_history_real)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function Over Iterations (Real Data)')
plt.show()

# Assert to check cost reduction
assert cost_history_real[-1] < cost_history_real[0], "Cost did not decrease for real data!"

# %% [markdown]
# ## Making Predictions on Real Data
# Once the model has been trained, we can now make predictions on the test set.

# %%
# Normalize the test data
X_test_scaled = scaler.transform(X_test)

# Add intercept term for the test data
X_test_b = np.c_[np.ones(X_test_scaled.shape[0]), X_test_scaled]


# Predicted prices using the final parameters for real data
y_pred_real = X_test_b.dot(theta_real)


# Plotting actual vs predicted prices
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual Prices')
plt.plot(range(len(y_test)), y_pred_real, color='red', label='Predicted Prices')
plt.xlabel('House Index')
plt.ylabel('Price (in dollars)')
plt.title('Actual vs Predicted House Prices (Real Data)')
plt.legend()
plt.show()

# Assert to check predictions length
assert len(y_pred_real) == len(y_test), "Prediction length mismatch for real data!"

# %% [markdown]
# ## Part 7: Experimenting with Hyperparameters for Real Data
# You can now experiment with different learning rates and iterations to observe their effects on the model.
#
# ### Tasks:
#
# Run the Gradient Descent with alpha=0.001, alpha=0.1, and alpha=0.05. Record the final cost and observe the impact of the learning rate.
# Try using different sets of features from the dataset. For example, you can add more features or remove certain features and see how the model's performance changes.

# %% [markdown]
# ### Final Note on Gradient Descent
# Gradient Descent is an optimization algorithm used to minimize the cost function in machine learning by iteratively adjusting model parameters. The algorithm calculates the gradient (slope) of the cost function and updates the parameters in the direction that reduces the error.
#
# - Learning Rate (α) controls the size of steps taken towards the minimum.
# - Iterations determine how many times the parameters are updated.
# - Convergence is reached when changes in the cost become negligible.
#
# Gradient Descent has variants like Batch, Stochastic, and Mini-Batch, each balancing between computation time and convergence stability. It is widely used in linear regression, neural networks, and more, making it essential for optimizing machine learning models.

# %% [markdown]
# ## Adding new feature

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the dataset
# Assuming the dataset is downloaded and named 'train.csv'
df = pd.read_csv('AmesHousing.csv')

# Select a few features (you can try different sets of features)

## Select Features by your own choice
features = ["Lot Area","House Style","Overall Qual","Overall Cond","Mas Vnr Area","Total Bsmt SF","Bedroom AbvGr","Year Built"]
target = 'SalePrice'

#Making dataframe of features
df_features = df[features]

# %%
# Extracting features (keep as DataFrame for one-hot encoding)
X_real = df[features]
y_real = df[target].values  #numpy array

# Step 1: One-Hot Encoding 'House Style' manually
house_styles = X_real['House Style'].unique()  # Get unique categories
house_style_dummies = pd.DataFrame(0, index=X_real.index, columns=house_styles)

for style in house_styles:
    house_style_dummies[style] = (X_real['House Style'] == style).astype(int)

# Step 2: Drop the original 'House Style' column and concatenate encoded columns
X_real = X_real.drop(columns=['House Style'])
X_real = pd.concat([X_real, house_style_dummies], axis=1)

# Step 3: Convert X_real to a NumPy array for further processing
X_real = X_real.values

# Now X_real is a NumPy array and ready for use
print(X_real.shape)
# Out:
# (2930, 15)

# %%
import numpy as np
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_real, y_real, test_size=0.2, random_state=42)

# Normalize features for better convergence
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Add a column of ones for the intercept term
X_train_b = np.c_[np.ones(X_train_scaled.shape[0]), X_train_scaled]

print(X_train_b.shape)
# Out:
# (2344, 16)

# %% [markdown]
# ## Applying gradient descent

# %%
# Initialize parameters (weights vector) with zeros
theta_real = np.zeros(X_train_b.shape[1])

# Define learning rate and number of iterations (You can experiment with these values)
alpha_real = [0.001,0.1,0.5]
iterations_real = 1000

# In case of having NaN values in the dataset, replace them with 0
X_train_b = np.nan_to_num(X_train_b)  # Replace NaNs with 0

# Use the gradient_descent function
for alpha in alpha_real:
    theta_real, cost_history_real = gradient_descent(X_train_b, y_train, theta_real, alpha, iterations_real)
    print("Alpha is",alpha,":","\n",theta_real)
    print(cost_history_real)

# Assert statement to check theta shape
assert theta_real.shape == (X_train_b.shape[1],), "Theta shape mismatch for real dataset!"
# Out:
# Alpha is 0.001 :
#  [112918.347024     8466.86425007  26102.15015164   1414.81177212
#   12080.7647659   18124.60346139   3754.97416331  13983.18039485
#   -3464.74700122   5743.37822552  -1445.0871288   -1876.66474285
#   -1046.3741598     911.74677848  -1581.22762732   2135.95620519]
# [18918672055.110283, 18876513505.076267, 18834470211.851646, 18792541781.41479, 18750727821.398903, 18709027941.084084, 18667441751.389458, 18625968864.865334, 18584608895.685417, 18543361459.639034, 18502226174.123436, 18461202658.136097, 18420290532.267086, 18379489418.69147, 18338798941.161743, 18298218725.000305, 18257748397.091972, 18217387585.876545, 18177135921.341385, 18136993035.014038, 18096958559.954914, 18057032130.749992, 18017213383.50354, 17977501955.830914, 17937897486.851357, 17898399617.180866, 17859007988.925064, 17819722245.672123, 17780542032.485733, 17741466995.898094, 17702496783.902943, 17663631045.948627, 17624869432.931183, 17586211597.187515, 17547657192.488518, 17509205874.03232, 17470857298.4375, 17432611123.73638, 17394467009.368324, 17356424616.173077, 17318483606.38414, 17280643643.622208, 17242904392.888577, 17205265520.558636, 17167726694.375383, 17130287583.442959, 17092947858.22023, 17055707190.514393, 17018565253.4746, 16981521721.58567, 16944576270.661757, 16907728577.840101, 16870978321.574799, 16834325181.630596, 16797768839.076733, 16761308976.280783, 16724945276.902584, 16688677425.888113, 16652505109.463488, 16616428015.128927, 16580445831.652777, 16544558249.065556, 16508764958.654024, 16473065652.955297, 16437460025.750994, 16401947772.061373, 16366528588.139563, 16331202171.465754, 16295968220.741478, 16260826435.883886, 16225776518.020052, 16190818169.481308, 16155951093.797655, 16
.7778004, 763925661.300394, 763925625.4770997, 763925591.2348325, 763925558.5037422, 763925527.2170691, 763925497.3110079, 763925468.7245753, 763925441.3994863, 763925415.2800332, 763925390.3129731, 763925366.447417, 763925343.634726, 763925321.8284125, 763925300.9840431, 763925281.0591491, 763925262.0131395, 763925243.8072168, 763925226.4042982, 763925209.7689396, 763925193.8672639, 763925178.6668895, 763925164.1368665, 763925150.24 ...
# Alpha is 0.5 :
#  [178582.20776451  10473.68348512  37604.87466682   5084.80180874
#    8845.86573919  20077.85193328   2072.17370313  12446.0446465
#   -4945.68321131   5372.72132075   1374.74728852  -1416.45373237
#   -1300.14403525    747.42215877  -1697.61965805   3021.76930794]
# [763924849.042652, 763924849.0426521, 763924849.0426519, 763924849.0426521, 763924849.0426521, 763924849.0426521, 763924849.042652, 763924849.0426521, 763924849.0426519, 763924849.042652, 763924849.042652, 763924849.0426521, 763924849.0426521, 763924849.0426519, 763924849.0426521, 763924849.0426521, 763924849.042652, 763924849.0426519, 763924849.0426521, 763924849.0426519, 763924849.0426519, 763924849.042652, 763924849.042652, 763924849.042652, 763924849.0426521, 763924849.0426519, 763924849.042652, 763924849.0426521, 763924849.0426521, 763924849.0426519, 763924849.042652, 763924849.042652, 763924849.0426521, 763924849.0426519, 763924849.042652, 763924849.0426519, 763924849.042652, 763924849.0426521, 763924849.0426519, 763924849.0426521, 763924849.042652, 763924849.0426519, 763924849.042652, 763924849.042652, 763924849.042652, 763924849.0426519, 763924849.0426521, 763924849.042652, 763924849.042652, 763924849.0426521, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.042652, 763924849.042652, 763924849.042652, 763924849.042652, 763924849.042652, 763924849.042652, 763924849.0426521, 763924849.0426519, 763924849.042652, 763924849.0426519, 763924849.0426519, 763924849.042652, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.042652, 763924849.042652, 763924849.0426519, 763924849.0426519, 763924849.042652, 763924849.0426519, 763924849.0426521, 763924849.0426521, 763924849.0426519, 763924849.042652, 763924849.0426519, 763924849.042652, 763924849.042652, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.042652, 763924849.0426521, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 763924849.0426519, 76392 ...

# %% [markdown]
# We can see here that when alpha =0.001, steps are very small and cost is large. <br>
# When alpha is equal to 0.1, steps are relatively large and there is noticable reduction in cost. <br>
# When alpha is 0.1 the starting cost is relatively small but the reduction in cost is even smaller than alpha=0.001.

# %% [markdown]
# ## Plotting alpha 0.5 prediction

# %%
# Normalize the test data
X_test_scaled = scaler.transform(X_test)

# Add intercept term for the test data
X_test_b = np.c_[np.ones(X_test_scaled.shape[0]), X_test_scaled]


# Predicted prices using the final parameters for real data
y_pred_real = X_test_b.dot(theta_real)


# Plotting actual vs predicted prices
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual Prices')
plt.plot(range(len(y_test)), y_pred_real, color='red', label='Predicted Prices')
plt.xlabel('House Index')
plt.ylabel('Price (in dollars)')
plt.title('Actual vs Predicted House Prices (Real Data)')
plt.legend()
plt.show()

# Assert to check predictions length
assert len(y_pred_real) == len(y_test), "Prediction length mismatch for real data!"
